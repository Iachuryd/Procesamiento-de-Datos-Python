# %% [markdown]
# # 🐍 Procesamiento de Datos — Python
#
# | Campo | Detalle |
# |---|---|
# | **Tema del cuaderno** | Condicionales |
# | **Autor** | Isabella Achury Dussán |
# | **Asignatura** | Procesamiento de Datos |
# | **Semestre** | 6 |
# | **Fecha** | [dd/mm/aaaa] |
#
# **Descripción personal del cuaderno:**
# > Uso de if, elif, else, operadores lógicos y de comparación. [Amplía en 2-4 líneas con tus propias palabras qué se trabaja en este cuaderno y qué esperas lograr con los ejercicios.]
#
# ---

# %% [markdown]
# ## Ejercicio 1
#
# **Instrucción (documentación breve, explícita y personal):**
# > [Explica en tus propias palabras qué pide el ejercicio y, si aplica, qué algoritmo o lógica vas a usar para resolverlo. No copies el enunciado literal.]

# %%
# Ejecución de la actividad
# Escribe aquí tu código

# %% [markdown]
# **Conclusión del ejercicio:**
# > [Qué aprendiste con este ejercicio, qué dificultad tuviste y cómo la resolviste.]
#
# ---

# %% [markdown]
# ## Ejercicio 2
#
# **Instrucción (documentación breve, explícita y personal):**
# > [Explica en tus propias palabras qué pide el ejercicio y, si aplica, qué algoritmo o lógica vas a usar para resolverlo. No copies el enunciado literal.]

# %%
# Ejecución de la actividad
# Escribe aquí tu código

# %% [markdown]
# **Conclusión del ejercicio:**
# > [Qué aprendiste con este ejercicio, qué dificultad tuviste y cómo la resolviste.]
#
# ---

# %% [markdown]
# ## Conclusiones del cuaderno
#
# > [Cierra el cuaderno con una reflexión personal sobre lo aprendido en "Condicionales": qué conceptos quedaron claros, cuáles requieren más práctica, y en qué casos reales aplicarías esto.]
